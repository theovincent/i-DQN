# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt
import json

experiment_name = "q30_N5000_b50_b12_f500_t5_lr4"
bellman_iterations_scope = 1
seed = 1
p = json.load(open(f"figures/{experiment_name}/parameters.json"))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
ifqi_loss = np.load(f"figures/{experiment_name}/iFQI/{bellman_iterations_scope}_L_{seed}.npy")
plt.plot(ifqi_loss)
_ = plt.title(f"iFQI training loss, {bellman_iterations_scope * p['fitting_steps_per_bellman_iteration']} training steps for forward moves\n {p['target_update_frequency']} target update frequency")
