# %%
# %load_ext blackcellmagic 
# %%black -l 120
# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

# %%
from experiments.atari import AVAILABLE_COLORS

plt.rc("font", family="serif", serif="Times New Roman", size=20)
plt.rc("lines", linewidth=3)

fig = plt.figure(figsize=(6, 1))
ax = fig.add_subplot(111)
ax.set_axis_off()


selected_lines = [
    Line2D([], [], color=AVAILABLE_COLORS["green"], linestyle="dashed"),
    Line2D([], [], color=AVAILABLE_COLORS["green"], linestyle="solid"),
    Line2D([], [], color=AVAILABLE_COLORS["pink"], linestyle="dashed"),
    Line2D([], [], color=AVAILABLE_COLORS["pink"], linestyle="solid"),
]
selected_legends = ["i-DQN", "DQN", "i-IQN", "IQN"]

fig.legend(selected_lines, selected_legends, ncols=2, frameon=False, loc="center")
_ = fig.savefig(f"figures/legend/atari_main_legend.pdf", bbox_inches="tight")

# %%
from experiments.atari import AVAILABLE_COLORS

plt.rc("font", family="serif", serif="Times New Roman", size=20)
plt.rc("lines", linewidth=3)

fig = plt.figure(figsize=(6, 1))
ax = fig.add_subplot(111)
ax.set_axis_off()


selected_lines = [
    Line2D([], [], color=AVAILABLE_COLORS["green"], linestyle="dashed"),
    Line2D([], [], color=AVAILABLE_COLORS["green"], linestyle="solid"),
    Line2D([], [], color=AVAILABLE_COLORS["orange"], linestyle="solid"),
]
selected_legends = ["i-DQN K=4, G=4", "DQN, G=4", "DQN, G=1"]

fig.legend(selected_lines, selected_legends, ncols=2, frameon=False, loc="center")
_ = fig.savefig(f"figures/legend/atari_ablation_G_legend.pdf", bbox_inches="tight")

# %%
from experiments.atari import AVAILABLE_COLORS

plt.rc("font", family="serif", serif="Times New Roman", size=20)
plt.rc("lines", linewidth=3)

fig = plt.figure(figsize=(6, 1))
ax = fig.add_subplot(111)
ax.set_axis_off()


selected_lines = [
    Line2D([], [], color=AVAILABLE_COLORS["green"], linestyle="dashed"),
    Line2D([], [], color=AVAILABLE_COLORS["green"], linestyle="solid"),
]
selected_legends = ["i-DQN K=4, T=2000", "DQN, T=8000"]

fig.legend(selected_lines, selected_legends, ncols=1, frameon=False, loc="center")
_ = fig.savefig(f"figures/legend/atari_ablation_Bellman_legend.pdf", bbox_inches="tight")

# %%
from experiments.atari import AVAILABLE_COLORS

plt.rc("font", family="serif", serif="Times New Roman", size=20)
plt.rc("lines", linewidth=3)

fig = plt.figure(figsize=(6, 1))
ax = fig.add_subplot(111)
ax.set_axis_off()


selected_lines = [
    Line2D([], [], color=AVAILABLE_COLORS["green"], linestyle="solid"),
    Line2D([], [], color=AVAILABLE_COLORS["green"], linestyle="dashed"),
    Line2D([], [], color=AVAILABLE_COLORS["orange"], linestyle="dashed"),
]
selected_legends = ["DQN (i-DQN K=1)", "i-DQN K=5", "i-DQN K=10"]

fig.legend(selected_lines, selected_legends, ncols=3, frameon=False, loc="center")
_ = fig.savefig(f"figures/legend/K_legend.pdf", bbox_inches="tight")

# %%
from experiments.atari import AVAILABLE_COLORS

plt.rc("font", family="serif", serif="Times New Roman", size=20)
plt.rc("lines", linewidth=3)

fig = plt.figure(figsize=(6, 1))
ax = fig.add_subplot(111)
ax.set_axis_off()


selected_lines = [
    Line2D([], [], color=AVAILABLE_COLORS["green"], linestyle="dashed"),
    Line2D([], [], color=AVAILABLE_COLORS["green"], linestyle="solid"),
    Line2D([], [], color=AVAILABLE_COLORS["pink"], linestyle="dashed"),
    Line2D([], [], color=AVAILABLE_COLORS["pink"], linestyle="solid"),
]
selected_legends = ["i-DQN K=5", "DQN + 5-step", "i-DQN K=5 + 3-step", "DQN + 3-step"]

fig.legend(selected_lines, selected_legends, ncols=2, frameon=False, loc="center", columnspacing=1.5, handlelength=2)
_ = fig.savefig(f"figures/legend/atari_n_step_legend.pdf", bbox_inches="tight")

# %%
from experiments.atari import AVAILABLE_COLORS

plt.rc("font", family="serif", serif="Times New Roman", size=20)
plt.rc("lines", linewidth=3)

fig = plt.figure(figsize=(6, 1))
ax = fig.add_subplot(111)
ax.set_axis_off()


selected_lines = [
    Line2D([], [], color=AVAILABLE_COLORS["red"], linestyle="dashed"),
    Line2D([], [], color=AVAILABLE_COLORS["green"], linestyle="dashed"),
]
selected_legends = ["i-DQN w/o target nets", "DQN w/ target nets"]

fig.legend(selected_lines, selected_legends, ncols=2, frameon=False, loc="center", columnspacing=1.5, handlelength=2)
_ = fig.savefig(f"figures/legend/atari_ablation_Delayed_legend.pdf", bbox_inches="tight")

# %%
from experiments.atari import AVAILABLE_COLORS

plt.rc("font", family="serif", serif="Times New Roman", size=20)
plt.rc("lines", linewidth=3)

fig = plt.figure(figsize=(6, 1))
ax = fig.add_subplot(111)
ax.set_axis_off()


selected_lines = [
    Line2D([], [], color=AVAILABLE_COLORS["brown"], linestyle="solid"),
    Line2D([], [], color=AVAILABLE_COLORS["green"], linestyle="solid"),
    Line2D([], [], color=AVAILABLE_COLORS["green"], linestyle="dashed"),
]
selected_legends = ["DQN (our implementation)", "DQN (dopamine)", "i-DQN K=1"]

fig.legend(selected_lines, selected_legends, ncols=2, frameon=False, loc="center", columnspacing=1.5, handlelength=2)
_ = fig.savefig(f"figures/legend/DQN_legend.pdf", bbox_inches="tight")

# %%
from experiments.atari import AVAILABLE_COLORS

plt.rc("font", family="serif", serif="Times New Roman", size=20)
plt.rc("lines", linewidth=3)

fig = plt.figure(figsize=(6, 1))
ax = fig.add_subplot(111)
ax.set_axis_off()


selected_lines = [
    Line2D([], [], color=AVAILABLE_COLORS["brown"], linestyle="solid"),
    Line2D([], [], color=AVAILABLE_COLORS["pink"], linestyle="solid"),
]
selected_legends = ["DQN + 3-step (our implementation)", "DQN + 3-step (dopamine)"]

fig.legend(selected_lines, selected_legends, ncols=1, frameon=False, loc="center")
_ = fig.savefig(f"figures/legend/DQN_3_steps_legend.pdf", bbox_inches="tight")

# %%
from experiments.atari import AVAILABLE_COLORS

plt.rc("font", family="serif", serif="Times New Roman", size=20)
plt.rc("lines", linewidth=3)

fig = plt.figure(figsize=(6, 1))
ax = fig.add_subplot(111)
ax.set_axis_off()


selected_lines = [
    Line2D([], [], color=AVAILABLE_COLORS["brown"], linestyle="solid"),
    Line2D([], [], color=AVAILABLE_COLORS["green"], linestyle="solid"),
    Line2D([], [], color=AVAILABLE_COLORS["green"], linestyle="dashed"),
]
selected_legends = ["IQN w/o 3-step (our implementation)", "IQN w/o 3-step (dopamine)", "i-IQN K=1 w/o 3-step"]

fig.legend(selected_lines, selected_legends, ncols=2, frameon=False, loc="center", columnspacing=1.5, handlelength=2)
_ = fig.savefig(f"figures/legend/IQN_legend.pdf", bbox_inches="tight")

# %%
from experiments.atari import AVAILABLE_COLORS

plt.rc("font", family="serif", serif="Times New Roman", size=20)
plt.rc("lines", linewidth=3)

fig = plt.figure(figsize=(6, 1))
ax = fig.add_subplot(111)
ax.set_axis_off()


selected_lines = [
    Line2D([], [], color=AVAILABLE_COLORS["orange"], linestyle="solid"),
    Line2D([], [], color=AVAILABLE_COLORS["yellow"], linestyle="solid"),
]
selected_legends = ["IQN (our implementation)", "IQN (dopamine)"]

fig.legend(selected_lines, selected_legends, ncols=1, frameon=False, loc="center")
_ = fig.savefig(f"figures/legend/IQN_3_steps_legend.pdf", bbox_inches="tight")

# %%
from experiments.atari import AVAILABLE_COLORS

plt.rc("font", family="serif", serif="Times New Roman", size=20)
plt.rc("lines", linewidth=3)

fig = plt.figure(figsize=(6, 1))
ax = fig.add_subplot(111)
ax.set_axis_off()


selected_lines = [
    Line2D([], [], color=AVAILABLE_COLORS["green"], linestyle="dashed"),
    Line2D([], [], color=AVAILABLE_COLORS["cyan"], linestyle="dashed"),
]
selected_legends = ["i-DQN (shared networks)", "i-DQN (independent networks)"]

fig.legend(selected_lines, selected_legends, ncols=2, frameon=False, loc="center")
_ = fig.savefig(f"figures/legend/atari_ablation_independent_legend.pdf", bbox_inches="tight")

# %%
from experiments.atari import AVAILABLE_COLORS

plt.rc("font", family="serif", serif="Times New Roman", size=20)
plt.rc("lines", linewidth=3)

fig = plt.figure(figsize=(6, 1))
ax = fig.add_subplot(111)
ax.set_axis_off()


selected_lines = [
    Line2D([], [], color=AVAILABLE_COLORS["green"], linestyle="dashed"),
    Line2D([], [], color=AVAILABLE_COLORS["green"], linestyle="solid"),
    Line2D([], [], color=AVAILABLE_COLORS["brown"], linestyle="solid"),
]
selected_legends = ["i-DQN K=5", "DQN", "DQN with 5 times more parameters"]

fig.legend(selected_lines, selected_legends, ncols=2, frameon=False, loc="center")
_ = fig.savefig(f"figures/legend/inflated_legend.pdf", bbox_inches="tight")
